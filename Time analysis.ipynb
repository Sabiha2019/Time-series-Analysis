# %%
# !pip install EMD-signal
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
import numpy as np
from scipy.signal import detrend  
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df2 = pd.read_csv('Weekly demand of a spare part p271 Montgomery.csv')

# %%
df2.dtypes
# Out:
# Week      int64
# Demand    int64
# dtype: object

# %%
df2.head()
# Out:
#    Week  Demand
# 0     1     260
# 1     2     251
# 2     3     235
# 3     4     234
# 4     5     287

# %%
df2 = pd.read_csv('Weekly demand of a spare part p271 Montgomery.csv', parse_dates = ['Week'], index_col = 'Week')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15620\3351070602.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2 = pd.read_csv('Weekly demand of a spare part p271 Montgomery.csv', parse_dates = ['Week'], index_col = 'Week')

# %%
df2[50:100]
# Out:
#       Demand
# Week
# 51       420
# 52       442
# 53       457
# 54       477
# 55       443
# 56       410
# 57       399
# 58       424
# 59       468
# 60       480

# %%
df2.loc[40]
# Out:
# Demand    365
# Name: 40, dtype: int64

# %%
df2.plot()
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] =5,5
df2.plot()
plt.show()

# %%
df2_mul_decompose= STL(df2["Demand"], period=10)
result = df2_mul_decompose.fit()
result.plot()
plt.show()

# %%
df2_mul_decompose = seasonal_decompose(df2, model="multiplicative", period=10)
df2_mul_decompose.plot()
plt.show()
